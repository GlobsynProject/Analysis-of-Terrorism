# %% [markdown]
# ## 1. Getting Data Ready

# %%
# Import All the necessary module used in the analysis of the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import calendar
import copy
from seaborn import set

# %%
# Load the DataSet contaning the data for global analysis of terrorism
# into a panda DataFrame data

# %%
try:
    data = pd.read_csv('E:\DataSet.csv')
    print('File successfully loaded into the DataFrame..')
except:
    print("File not found...")
# Out:
# File successfully loaded into the DataFrame..

# %% [markdown]
# ## 2.Displaying the different features of the DataSet

# %%
# Show all the columns present in the dataSet
data.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'city', 'attacktype1_txt',
#        'targtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'gname',
#        'weaptype1_txt', 'weapsubtype1_txt', 'weapdetail', 'nkill', 'nwound',
#        'propextent_txt', 'ransomamt'],
#       dtype='object')

# %%
# Displaying the first 10 data of the DataSet
data.head(10)
# Out:
#    iyear  imonth  iday                       country_txt               city  \
# 0   2012       1     1                             Kenya            Garissa
# 1   2012       1     1                          Pakistan                Sui
# 2   2012       1     1                             Kenya            Garissa
# 3   2012       1     1                       Afghanistan              Karez
# 4   2012       1     1  Democratic Republic of the Congo           Shabunda
# 5   2012       1     1                     United States          Pensacola
# 6   2012       1     2                             India  Tinsukia district
# 7   2012       1     2                       Afghanistan          Puli Alam
# 8   2012       1     2                           Senegal           Affiniam
# 9   2012       1     2                           Somalia         Beledweyne
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
# 5  Facility/Infrastructure Attack             Abortion Related
# 6               Bombing/Explosion  Private Citizens & Property
# 7               Bombing/Explosion  Private Citizens & Property
# 8                   Armed Assault                     Military
# 9                   Armed Assault  Private Citizens & Property
#
#                                                corp1    target1  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
# 5                           American Family Planning     Clinic
# 6                                     Not Applicable  Civilians
# 7                                     Not Applicable  Civilians
# 8                             Senegalese Gendarmerie   Officers
# 9                                     Not Applicable  Civilians
#
#                         natlty1_txt  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
# 5                     United States
# 6                             India
# 7                       Afghanistan
# 8                           Senegal
# 9                           Somalia
#
#                                                gname  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
# 5                           Anti-Abortion extremists
# 6            United Liberation Front of Assam (ULFA)
# 7                                            Taliban
# 8         Movement of Democratic Forces of Casamance
# 9                            Shabelle Valley militia
#
#                weaptype1_txt              weapsubtype1_txt  \
# 0  Explosives/Bombs/Dynamite                       Grenade
# 1  Explosives/Bombs/Dynamite                     Land Mine
# 2  Explosives/Bombs/Dynamite                       Grenade
# 3  Explosives/Bombs/Dynamite        Unknown Explosive Type
# 4                 Incendiary                    Arson/Fire
# 5                 Incendiary  Molotov Cocktail/Petrol Bomb
# 6  Explosives/Bombs/Dynamite                       Grenade
# 7  Explosives/Bombs/Dynamite                     Land Mine
# 8                   Firearms              Unknown Gun Type
# 9                   Firearms              Unknown Gun Type
#
#                                           weapdetail  nkill  nwound  \
# 0  Two grenades and AK-47 assault rifles were use...    3.0    14.0
# 1                                                NaN    4.0     3.0
# 2                                                NaN    2.0    14.0
# 3                                                NaN    0.0     0.0
# 4                                                NaN   18.0     5.0
# 5                 A firebomb was used in the attack.    0.0     0.0
# 6                                                NaN    0.0     3.0
# 7                                                NaN    3.0     0.0
# 8                                                NaN    1.0     6.0
# 9                                                NaN    3.0     0.0
#
#                 propextent_txt  ransomamt
# 0  Minor (likely < $1 million)        NaN
# 1  Minor (likely < $1 million)        NaN
# 2  Minor (likely < $1 million)        NaN
# 3                      Unknown        NaN
# 4  Minor (likely < $1 million)        NaN
# 5  Minor (likely < $1 million)        NaN
# 6  Minor (likely < $1 million)        NaN
# 7  Minor (likely < $1 million)        NaN
# 8  Minor (likely < $1 million)        NaN
# 9                          NaN        NaN

# %%
# Displaying the last 10
data.tail(10)
# Out:
#        iyear  imonth  iday                       country_txt  \
# 43905   2016      12    31                       Afghanistan
# 43906   2016      12    31                       Afghanistan
# 43907   2016      12    31                       Afghanistan
# 43908   2016      12    30                       Afghanistan
# 43909   2016      12    31                       Afghanistan
# 43910   2016      12    31                             Niger
# 43911   2016      12    31                       Philippines
# 43912   2016      12    31  Democratic Republic of the Congo
# 43913   2016      12    31                            Mexico
# 43914   2016      12    30                             Sudan
#
#                     city              attacktype1_txt  \
# 43905            Jakdalk                      Unknown
# 43906           Shirkhel                      Unknown
# 43907              Tofan                      Unknown
# 43908  Mangajek district            Bombing/Explosion
# 43909        Lashkar Gah            Bombing/Explosion
# 43910             Garoua                      Unknown
# 43911            Talitay            Bombing/Explosion
# 43912         Nakolongbo  Hostage Taking (Kidnapping)
# 43913          Guachochi                Assassination
# 43914            Nertiti                Armed Assault
#
#                       targtype1_txt                                  corp1  \
# 43905                      Military  Afghan National Security Force (ANSF)
# 43906                      Military  Afghan National Security Force (ANSF)
# 43907                      Military  Afghan National Security Force (ANSF)
# 43908  Terrorists/Non-State Militia       National Uprising Movement (NUM)
# 43909   Private Citizens & Property                         Not Applicable
# 43910                      Military                             Niger Army
# 43911                           NGO                                Unknown
# 43912   Private Citizens & Property                     Nakolongbo Village
# 43913           Journalists & Media                                 Norawa
# 43914   Private Citizens & Property                          Nierteti Town
#
#                                                 target1  \
# 43905                                        Checkposts
# 43906                                        Checkposts
# 43907                                        Checkposts
# 43908                                           Vehicle
# 43909                                         Civilians
# 43910                                          Soldiers
# 43911                          Convoy of Relief Workers
# 43912                                           Village
# 43913  Residence of Journalist: Gabriel Valencia Juarez
# 43914                                              Town
#
#                             natlty1_txt                         gname  \
# 43905                       Afghanistan                       Taliban
# 43906                       Afghanistan                       Taliban
# 43907                       Afghanistan                       Taliban
# 43908                       Afghanistan                       Taliban
# 43909                       Afghanistan                       Unknown
# 43910                             Niger                    Boko Haram
# 43911                       Philippines                       Unknown
# 43912  Democratic Republic of the Congo  Lord's Resistance Army (LRA)
# 43913                            Mexico                       Unknown
# 43914                             Sudan     Sudan Liberation Movement
#
#                    weaptype1_txt        weapsubtype1_txt  \
# 43905                    Unknown                     NaN
# 43906                    Unknown                     NaN
# 43907                    Unknown                     NaN
# 43908  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 43909  Explosives/Bombs/Dynamite               Land Mine
# 43910                    Unknown                     NaN
# 43911  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 43912                    Unknown                     NaN
# 43913                   Firearms                 Handgun
# 43914                   Firearms        Unknown Gun Type
#
#                                            weapdetail  nkill  nwound  \
# 43905                                             NaN    1.0     1.0
# 43906                                             NaN    0.0     2.0
# 43907                                             NaN    0.0     1.0
# 43908                                             NaN    2.0     5.0
# 43909                                             NaN    1.0     6.0
# 43910                                             NaN   15.0     7.0
# 43911         A roadside bomb was used in the attack.    0.0     0.0
# 43912                                             NaN    0.0     NaN
# 43913  Multiple 9-mm pistols were used in the attack.    0.0     0.0
# 43914                                             NaN    0.0     0.0
#
#                     propextent_txt  ransomamt
# 43905                          NaN        NaN
# 43906                          NaN        NaN
# 43907                          NaN        NaN
# 43908  Minor (likely < $1 million)        NaN
# 43909                          NaN        NaN
# 43910                          NaN        NaN
# 43911                          NaN        NaN
# 43912                          NaN        NaN
# 43913  Minor (likely < $1 million)        NaN
# 43914                          NaN        NaN

# %%
# Shape of the DataFrame
data.shape
# Out:
# (43915, 18)

# %%
# Datatype of each coulmn
data.dtypes
# Out:
# iyear                 int64
# imonth                int64
# iday                  int64
# country_txt          object
# city                 object
# attacktype1_txt      object
# targtype1_txt        object
# corp1                object
# target1              object
# natlty1_txt          object
# gname                object
# weaptype1_txt        object
# weapsubtype1_txt     object
# weapdetail           object
# nkill               float64
# nwound              float64
# propextent_txt       object
# ransomamt           float64
# dtype: object

# %%
# Renaming the column for better understanding of the DataSet
data.rename({'iyear':'year','imonth':'month','iday':'day','country_txt':'country',\
               'attacktype1_txt':'attack','targtype1_txt':'target', 'corp1':'target_inst',\
               'target1':'target_pop', 'natlty1_txt':'nationality','gname':'group',\
               'weaptype1_txt':'weapon_type', 'weapsubtype1_txt':'weapon_subtype',\
               'nkill':'kill','nwound':'wound','propextent_txt':'property_damg', \
               'ransomamt':'ransom'}, axis='columns',inplace=True)

# %%
# Displaying the column after the rename operation
data.columns
# Out:
# Index(['year', 'month', 'day', 'country', 'city', 'attack', 'target',
#        'target_inst', 'target_pop', 'nationality', 'group', 'weapon_type',
#        'weapon_subtype', 'weapdetail', 'kill', 'wound', 'property_damg',
#        'ransom'],
#       dtype='object')

# %%
# General information about the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43915 entries, 0 to 43914
# Data columns (total 18 columns):
# year              43915 non-null int64
# month             43915 non-null int64
# day               43915 non-null int64
# country           43915 non-null object
# city              43915 non-null object
# attack            43915 non-null object
# target            43915 non-null object
# target_inst       43915 non-null object
# target_pop        43915 non-null object
# nationality       43342 non-null object
# group             43915 non-null object
# weapon_type       43915 non-null object
# weapon_subtype    39346 non-null object
# weapdetail        16985 non-null object
# kill              41290 non-null float64
# wound             39313 non-null float64
# property_damg     15615 non-null object
# ransom            273 non-null float64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 6.0+ MB

# %%
# Describing the statistical information only for numerical columns
data.describe()
# Out:
#                year         month           day          kill         wound  \
# count  43915.000000  43915.000000  43915.000000  41290.000000  39313.000000
# mean    2014.688079      6.442537     15.664716      3.110463      3.504006
# std        1.229350      3.390650      8.778536     13.343306     13.988988
# min     2012.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2014.000000      4.000000      8.000000      0.000000      0.000000
# 50%     2015.000000      6.000000     15.000000      1.000000      0.000000
# 75%     2016.000000      9.000000     23.000000      2.000000      3.000000
# max     2016.000000     12.000000     31.000000   1500.000000   1500.000000
#
#              ransom
# count  2.730000e+02
# mean   4.066460e+06
# std    2.180638e+07
# min   -9.900000e+01
# 25%   -9.900000e+01
# 50%    1.586045e+04
# 75%    2.189562e+05
# max    2.000000e+08

# %% [markdown]
# * MAXIMUM PEOPLE EVER KILLED IN AN EVENT IS 1500!
# * MAXIMUM PEOPLE EVER WOUNDED IN AN EVENT IS 1500!
# * 50% OF ATTACKS EITHER KILLED 1 PERSON OR NO-ONE
# * 50% OF ATTACKS WOUNDED NO-ONE!
# * MAXIMUM RANSOM AMOUNT ASKED EVER WAS 20 CRORES!
# * AVERAGE CASUALTIES PER ATTACK IS 6
# * MAXIMUM CASUALTIES EVRE IS 1503.

# %% [markdown]
# ## 3. Data Cleaning and Mangling

# %%
# Sum of null value in each column
data.isnull().sum()
# Out:
# year                  0
# month                 0
# day                   0
# country               0
# city                  0
# attack                0
# target                0
# target_inst           0
# target_pop            0
# nationality         573
# group                 0
# weapon_type           0
# weapon_subtype     4569
# weapdetail        26930
# kill               2625
# wound              4602
# property_damg     28300
# ransom            43642
# dtype: int64

# %% [markdown]
# ### $\color{red}{\text{Heat Map}}$ before filing up null values with suitable data

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP BEFORE FILLING UP NULL VALUES IN DATA')
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %% [markdown]
# * MOST OF THE RANSOM AMOUNTS,PROPERTY-DAMAGE EXTENTS,WEAPON DETAILS NOT PROVIDED WITH VALUES
# * MOST TERRORITS WERE INTERESTED IN MASS KILLING THAN PROCURING MONEY TO RELEASE HOSTAGE!
# * NOT MUCH PROPERTY DAMAGE OBSERVED

# %% [markdown]
# ### 3.1 Dealing with the null values of nationality

# %%
# Dealing with the null values of nationality
data[['country','nationality']].head(10)
# Out:
#                             country                       nationality
# 0                             Kenya                             Kenya
# 1                          Pakistan                          Pakistan
# 2                             Kenya                             Kenya
# 3                       Afghanistan                     International
# 4  Democratic Republic of the Congo  Democratic Republic of the Congo
# 5                     United States                     United States
# 6                             India                             India
# 7                       Afghanistan                       Afghanistan
# 8                           Senegal                           Senegal
# 9                           Somalia                           Somalia

# %% [markdown]
# It seems the values in the country of the terrorist attack and the nationality of terrorist is same as seen from the above data.
# Therefore, We can deall with the null value of the nationality column by replacing the values with country column.

# %%
# impute_nationality function will be applied te replace the null values in nationality column
def impute_nationality(cols):
    Country = cols[0]
    Nationality = cols[1]
    if pd.isnull(Nationality):
        return Country
    else:
        return Nationality

# %%
# Perform the replacement 
data['nationality'] = data[['country','nationality']].apply(impute_nationality, axis = 1)
data[['nationality','country']].head(10)
# Out:
#                         nationality                           country
# 0                             Kenya                             Kenya
# 1                          Pakistan                          Pakistan
# 2                             Kenya                             Kenya
# 3                     International                       Afghanistan
# 4  Democratic Republic of the Congo  Democratic Republic of the Congo
# 5                     United States                     United States
# 6                             India                             India
# 7                       Afghanistan                       Afghanistan
# 8                           Senegal                           Senegal
# 9                           Somalia                           Somalia

# %% [markdown]
# ### $\color{red}{\text{Heat Map}}$ after filing up null values for nationality

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP After FILLING UP NULL VALUES FOR NATIONALITY COLUMN')
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
print('The null values in nationality coulmn is ',data['nationality'].isnull().sum())
# Out:
# The null values in nationality coulmn is  0

# %% [markdown]
# ### 3.2 Dealing with duplicates in the data set

# %%
print('The no. of duplicates in the data are',data.duplicated().sum())
# Out:
# The no. of duplicates in the data are 1968

# %%
# Displaying the first 5 duplicates
data[data.duplicated()].head()
# Out:
#      year  month  day   country      city                          attack  \
# 56   2012      1    6   Nigeria  Potiskum  Facility/Infrastructure Attack
# 164  2012      1   20   Nigeria      Kano               Bombing/Explosion
# 165  2012      1   20   Nigeria      Kano               Bombing/Explosion
# 253  2012      1   31  Pakistan    Marwar                   Armed Assault
# 437  2012      2   23      Iraq     Mosul               Bombing/Explosion
#
#                 target                 target_inst            target_pop  \
# 56            Business                     Unknown                  Bank
# 164             Police  Nigeria Police Force (NPF)        Police Station
# 165             Police  Nigeria Police Force (NPF)        Police Station
# 253           Military         Frontier Corps (FC)            Checkpoint
# 437  Telecommunication                    Asiacell  Communications Tower
#
#     nationality                         group                weapon_type  \
# 56      Nigeria                    Boko Haram                   Firearms
# 164     Nigeria                    Boko Haram  Explosives/Bombs/Dynamite
# 165     Nigeria                    Boko Haram  Explosives/Bombs/Dynamite
# 253    Pakistan  Baloch Liberation Army (BLA)  Explosives/Bombs/Dynamite
# 437        Iraq              Al-Qaida in Iraq  Explosives/Bombs/Dynamite
#
#                                 weapon_subtype  \
# 56                            Unknown Gun Type
# 164                     Unknown Explosive Type
# 165                     Unknown Explosive Type
# 253  Projectile (rockets, mortars, RPGs, etc.)
# 437                                    Vehicle
#
#                                           weapdetail  kill  wound  \
# 56                                               NaN   0.0    0.0
# 164                                              NaN  17.0    5.0
# 165                                              NaN  17.0    5.0
# 253  Rockets and small arms were used in the attack.   4.0    3.0
# 437                                              NaN   0.0    0.0
#
#                    property_damg  ransom
# 56   Minor (likely < $1 million)     NaN
# 164  Minor (likely < $1 million)     NaN
# 165  Minor (likely < $1 million)     NaN
# 253                          NaN     NaN
# 437  Minor (likely < $1 million)     NaN

# %%
# Dropping the duplicated items
data.drop_duplicates(inplace=True)

# Showing the first five
data.head()
# Out:
#    year  month  day                           country      city  \
# 0  2012      1    1                             Kenya   Garissa
# 1  2012      1    1                          Pakistan       Sui
# 2  2012      1    1                             Kenya   Garissa
# 3  2012      1    1                       Afghanistan     Karez
# 4  2012      1    1  Democratic Republic of the Congo  Shabunda
#
#                            attack                       target  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
#
#                                          target_inst target_pop  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
#
#                         nationality  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
#
#                                                group  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
#
#                  weapon_type          weapon_subtype  \
# 0  Explosives/Bombs/Dynamite                 Grenade
# 1  Explosives/Bombs/Dynamite               Land Mine
# 2  Explosives/Bombs/Dynamite                 Grenade
# 3  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 4                 Incendiary              Arson/Fire
#
#                                           weapdetail  kill  wound  \
# 0  Two grenades and AK-47 assault rifles were use...   3.0   14.0
# 1                                                NaN   4.0    3.0
# 2                                                NaN   2.0   14.0
# 3                                                NaN   0.0    0.0
# 4                                                NaN  18.0    5.0
#
#                  property_damg  ransom
# 0  Minor (likely < $1 million)     NaN
# 1  Minor (likely < $1 million)     NaN
# 2  Minor (likely < $1 million)     NaN
# 3                      Unknown     NaN
# 4  Minor (likely < $1 million)     NaN

# %% [markdown]
# ### 3.3 Dealing with null values and unknown in weapon_type column

# %%
print(data['attack'].unique())
print('\nThere are',len(data['attack'].unique()),'unique values in attack column')
# Out:
# ['Armed Assault' 'Bombing/Explosion' 'Facility/Infrastructure Attack'
#  'Assassination' 'Unknown' 'Hostage Taking (Kidnapping)' 'Hijacking'
#  'Hostage Taking (Barricade Incident)' 'Unarmed Assault']
#
# There are 9 unique values in attack column

# %%
# Making a list of unique weapon type
# and forming columns for the unique values of weapon_type
wp_tp = pd.get_dummies(data['weapon_type'],drop_first=True)
list_wp_type = list(wp_tp.columns)
print('The values of column head are',list_wp_type)
# Out:
# The values of column head are ['Chemical', 'Explosives/Bombs/Dynamite', 'Fake Weapons', 'Firearms', 'Incendiary', 'Melee', 'Other', 'Sabotage Equipment', 'Unknown', 'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)']

# %%
# Making a new copy of the Data
data2 = copy.deepcopy(data)
data2 = pd.concat([data2,wp_tp],axis=1)

# %%
data2.groupby('attack').sum().reset_index().plot.barh(x='attack',y=list_wp_type,figsize=(16,8),stacked=True)
plt.legend(loc=5)
data2.groupby('attack').sum()[list_wp_type]
# Out:
#                                      Chemical  Explosives/Bombs/Dynamite  \
# attack
# Armed Assault                             0.0                     1191.0
# Assassination                             2.0                      685.0
# Bombing/Explosion                        31.0                    20414.0
# Facility/Infrastructure Attack            0.0                        0.0
# Hijacking                                 0.0                        8.0
# Hostage Taking (Barricade Incident)       0.0                       61.0
# Hostage Taking (Kidnapping)               3.0                      132.0
# Unarmed Assault                          36.0                        0.0
# Unknown                                   0.0                        0.0
#
#                                      Fake Weapons  Firearms  Incendiary  \
# attack
# Armed Assault                                 0.0    8280.0       209.0
# Assassination                                 0.0    1545.0         9.0
# Bombing/Explosion                             0.0       0.0         0.0
# Facility/Infrastructure Attack                0.0     296.0      1530.0
# Hijacking                                     1.0      78.0         5.0
# Hostage Taking (Barricade Incident)           0.0      92.0        17.0
# Hostage Taking (Kidnapping)                   0.0    1923.0        77.0
# Unarmed Assault                               0.0       0.0        12.0
# Unknown                                       0.0       0.0         0.0
#
#                                      Melee  Other  Sabotage Equipment  \
# attack
# Armed Assault                        460.0    0.0                 0.0
# Assassination                         71.0    1.0                 0.0
# Bombing/Explosion                      0.0    0.0                 0.0
# Facility/Infrastructure Attack        11.0    5.0                18.0
# Hijacking                              0.0    0.0                 0.0
# Hostage Taking (Barricade Incident)   11.0    0.0                 0.0
# Hostage Taking (Kidnapping)          295.0   18.0                 1.0
# Unarmed Assault                      107.0    8.0                 0.0
# Unknown                                0.0    0.0                 0.0
#
#                                      Unknown  \
# attack
# Armed Assault                            0.0
# Assassination                          105.0
# Bombing/Explosion                        0.0
# Facility/Infrastructure Attack         191.0
# Hijacking                               32.0
# Hostage Taking (Barricade Incident)     16.0
# Hostage Taking (Kidnapping)           1350.0
# Unarmed Assault                          0.0
# Unknown                               2552.0
#
#                                      Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)
# attack
# Armed Assault                                                                      0.0
# Assassination                                                                      1.0
# Bombing/Explosion                                                                  0.0
# Facility/Infrastructure Attack                                                     5.0
# Hijacking                                                                          0.0
# Hostage Taking (Barricade Incident)                                                0.0
# Hostage Taking (Kidnapping)                                                        0.0
# Unarmed Assault                                                                   49.0
# Unknown                                                                            0.0

# %%
data['attack'].value_counts(ascending=True).to_frame().reset_index().rename({'index':'attack','attack':'counts'})
# Out:
#                                  index  attack
# 0                            Hijacking     124
# 1  Hostage Taking (Barricade Incident)     197
# 2                      Unarmed Assault     215
# 3       Facility/Infrastructure Attack    2056
# 4                        Assassination    2419
# 5                              Unknown    2552
# 6          Hostage Taking (Kidnapping)    3799
# 7                        Armed Assault   10140
# 8                    Bombing/Explosion   20445

# %% [markdown]
# From the above graph We can say, A good replacement for unknown data in weapon_type would be:
# * Unarmed Assault- Melee
# * Hostage Taking(Kidnapping)- Firearms
# * Hostage Taking(Barricade Incident)- Firearms
# * Assassination - Firearms
# * Armed Assault - Firearms
# * Hijacking- Firearms
# * Facility/Infrastructure Attack- Incendiary
# * Bombing/Explosion- Explosives

# %%
# impute_nationality function will be applied te replace the null values in nationality column
def impute_weapon_type(cols):
    weapons = {'Armed Assault':'Firearms',
               'Bombing/Explosion':'Explosives/Bombs/Dynamite',
               'Facility/Infrastructure Attack':'Incendiary',
               'Assassination':'Firearms',
               'Hostage Taking (Kidnapping)':'Firearms',
               'Hijacking':'Firearms',
               'Unknown':'Unknown',
               'Hostage Taking (Barricade Incident)':'Firearms',
               'Unarmed Assault':'Melee'}
    Attack = cols[0]
    wpType = cols[1]
    if pd.isnull(wpType):
        return weapons[Attack]
    else:
        return wpType

# %%
# Perform the replacement 
data['weapon_type'] = data[['attack','weapon_type']].apply(impute_weapon_type, axis = 1)
data[['attack','weapon_type']].head()
# Out:
#                            attack                weapon_type
# 0                   Armed Assault  Explosives/Bombs/Dynamite
# 1               Bombing/Explosion  Explosives/Bombs/Dynamite
# 2                   Armed Assault  Explosives/Bombs/Dynamite
# 3               Bombing/Explosion  Explosives/Bombs/Dynamite
# 4  Facility/Infrastructure Attack                 Incendiary

# %% [markdown]
# ### $\color{red}{\text{Heat Map}}$ after filing up null values for weapon type

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP AFTER FILLING UP NULL VALUES FOR WEAPON TYPE')
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %% [markdown]
# ### 3.4 Dealing with null values  in kill and wound column

# %%
#Drop the column which has kill null and wound null
data.drop(data.loc[(data.kill.isnull())&(data.wound.isnull())].index,inplace = True)

# %%
#Drop the column which has kill and group Unknown
data.drop(data.loc[(data.kill.isnull())&(data.group=='Unknown')].index,inplace=True)

# %%
#Create a dataframe dd to store the mean of kill and wound based on weapon_subtype
dd = data.groupby('weapon_subtype').mean()[['kill','wound']].reset_index()
dd = dd.astype({'kill':int,'wound':int},inplace=True)
dd
# Out:
#                                weapon_subtype  kill  wound
# 0                                  Arson/Fire     1      0
# 1                            Automatic Weapon     3      2
# 2                                Blunt Object     0      2
# 3                                Dynamite/TNT     0      0
# 4                                   Explosive     2     66
# 5                         Gasoline or Alcohol     0      1
# 6                                     Grenade     1      3
# 7                                     Handgun     1      1
# 8                          Hands, Feet, Fists     0      2
# 9                 Knife or Other Sharp Object     2      1
# 10                                  Land Mine     1      2
# 11                                Letter Bomb     1      4
# 12               Molotov Cocktail/Petrol Bomb     0      0
# 13                       Other Explosive Type     0      1
# 14                             Other Gun Type     0      1
# 15                                  Poisoning     0     56
# 16                           Pressure Trigger     1      1
# 17  Projectile (rockets, mortars, RPGs, etc.)     3      3
# 18                             Remote Trigger     1      3
# 19              Rifle/Shotgun (non-automatic)     1      0
# 20            Rope or Other Strangling Device     2      0
# 21                                Sticky Bomb     0      2
# 22    Suicide (carried bodily by human being)     9     14
# 23                                  Time Fuse     0      3
# 24                     Unknown Explosive Type     1      2
# 25                           Unknown Gun Type     3      1
# 26                        Unknown Weapon Type     0      2
# 27                                    Vehicle     6     11

# %%
# We will remove the remaining null values in kill and wound by mean values
def impute_kill(cols):
    kill = cols[0]
    wp_sb = cols[1]
    if pd.isnull(kill):
        return dd[dd.weapon_subtype==wp_sb].kill.sum()
    else: 
        return kill

def impute_wound(cols):
    wound = cols[0]
    wp_sb = cols[1]
    if pd.isnull(wound):
        
        return dd[dd.weapon_subtype==wp_sb].wound.sum()
    else:
        return wound

# %%
data['kill']=data[['kill','weapon_subtype']].apply(impute_kill,axis=1)

# %%
data['wound']=data[['wound','weapon_subtype']].apply(impute_wound,axis=1)

# %% [markdown]
# ### $\color{red}{\text{Heat Map}}$ after filing up null values for kill and wound

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP AFTER FILLING UP NULL VALUES FOR KILL AND WOUND')
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')
data.head()
# Out:
#    year  month  day                           country      city  \
# 0  2012      1    1                             Kenya   Garissa
# 1  2012      1    1                          Pakistan       Sui
# 2  2012      1    1                             Kenya   Garissa
# 3  2012      1    1                       Afghanistan     Karez
# 4  2012      1    1  Democratic Republic of the Congo  Shabunda
#
#                            attack                       target  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
#
#                                          target_inst target_pop  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
#
#                         nationality  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
#
#                                                group  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
#
#                  weapon_type          weapon_subtype  \
# 0  Explosives/Bombs/Dynamite                 Grenade
# 1  Explosives/Bombs/Dynamite               Land Mine
# 2  Explosives/Bombs/Dynamite                 Grenade
# 3  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 4                 Incendiary              Arson/Fire
#
#                                           weapdetail  kill  wound  \
# 0  Two grenades and AK-47 assault rifles were use...   3.0   14.0
# 1                                                NaN   4.0    3.0
# 2                                                NaN   2.0   14.0
# 3                                                NaN   0.0    0.0
# 4                                                NaN  18.0    5.0
#
#                  property_damg  ransom
# 0  Minor (likely < $1 million)     NaN
# 1  Minor (likely < $1 million)     NaN
# 2  Minor (likely < $1 million)     NaN
# 3                      Unknown     NaN
# 4  Minor (likely < $1 million)     NaN

# %% [markdown]
# ### 3.5 Dealing with null values  in weapon_subtype, weapdetail, ransom and property_damp column

# %%
# Dealing with the null values of weapon_subtype, weapdetail, ransom and property_damg
data['weapon_subtype'].fillna('Unknown', inplace = True)
data['weapdetail'].fillna('Unknown', inplace = True)
data['ransom'].fillna(0, inplace = True)
data['property_damg'].fillna('no record', inplace = True)
print('No. of rows after dropping nulls:',data['kill'].count())
# Out:
# No. of rows after dropping nulls: 39572

# %% [markdown]
# ### $\color{red}{\text{Heat Map}}$ after filing up null values for  weapon_subtype, weapdetail, ransom and property_damp column

# %%
plt.figure(figsize=(10,3))
plt.rcParams['axes.labelsize']=15
plt.rcParams['ytick.labelsize']=13
plt.rcParams['xtick.labelsize']=13
plt.title('HEATMAP AFTER FILLING UP NULL VALUES FOR KILL AND WOUND')
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %% [markdown]
# Now we have neat and clear data, and successfully saved over 39,752 rows

# %%
# Adding a new column Casualties which shows the no. of people killed and wounded in a particular attack
data['casualties']= data['kill'] + data['wound']

# %%
# The DataSet after the aforesaid changes
data.head()
# Out:
#    year  month  day                           country      city  \
# 0  2012      1    1                             Kenya   Garissa
# 1  2012      1    1                          Pakistan       Sui
# 2  2012      1    1                             Kenya   Garissa
# 3  2012      1    1                       Afghanistan     Karez
# 4  2012      1    1  Democratic Republic of the Congo  Shabunda
#
#                            attack                       target  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
#
#                                          target_inst target_pop  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
#
#                         nationality  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
#
#                                                group  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
#
#                  weapon_type          weapon_subtype  \
# 0  Explosives/Bombs/Dynamite                 Grenade
# 1  Explosives/Bombs/Dynamite               Land Mine
# 2  Explosives/Bombs/Dynamite                 Grenade
# 3  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 4                 Incendiary              Arson/Fire
#
#                                           weapdetail  kill  wound  \
# 0  Two grenades and AK-47 assault rifles were use...   3.0   14.0
# 1                                            Unknown   4.0    3.0
# 2                                            Unknown   2.0   14.0
# 3                                            Unknown   0.0    0.0
# 4                                            Unknown  18.0    5.0
#
#                  property_damg  ransom  casualties
# 0  Minor (likely < $1 million)     0.0        17.0
# 1  Minor (likely < $1 million)     0.0         7.0
# 2  Minor (likely < $1 million)     0.0        16.0
# 3                      Unknown     0.0         0.0
# 4  Minor (likely < $1 million)     0.0        23.0

# %% [markdown]
# ## 4. Some Basic Analysis on Global Terror Attacks

# %%
data.corr() #strong relation b/w casualties and 1.wound,2.kill.. wound and casualties
# Out:
#                 year     month       day      kill     wound    ransom  \
# year        1.000000 -0.028153 -0.003866 -0.018178 -0.022777 -0.014729
# month      -0.028153  1.000000  0.005342  0.006790  0.000086  0.006050
# day        -0.003866  0.005342  1.000000 -0.009339 -0.002343  0.003613
# kill       -0.018178  0.006790 -0.009339  1.000000  0.219623 -0.002761
# wound      -0.022777  0.000086 -0.002343  0.219623  1.000000 -0.003663
# ransom     -0.014729  0.006050  0.003613 -0.002761 -0.003663  1.000000
# casualties -0.026257  0.004351 -0.007426  0.774850  0.786886 -0.004120
#
#             casualties
# year         -0.026257
# month         0.004351
# day          -0.007426
# kill          0.774850
# wound         0.786886
# ransom       -0.004120
# casualties    1.000000

# %% [markdown]
# * NOT MUCH CORRELATION BETWEEN ANY VALUES EXCEPT BETWEEN CASUALITIES WITH KILLS AND WOUNDED

# %%
max_killed = data['kill'].max()
idx = data.loc[data.kill==max_killed].index[0]
print('Maximum people killed in an attack are',max_killed,\
      '\nin the city',data.at[idx,'city'],'of',data.at[idx,'country'],\
     '\nwhich was carried by',data.at[idx,'group'],'using',data.at[idx,'weapon_type'],\
     '\nand maximum people killed were',data.at[idx,'target'],'who were',data.at[idx,'attack'])
# Out:
# Maximum people killed in an attack are 1500.0
# in the city Tikrit of Iraq
# which was carried by Islamic State of Iraq and the Levant (ISIL) using Firearms
# and maximum people killed were Military who were Hostage Taking (Kidnapping)

# %% [markdown]
# ### 4.1 Graphical Analysis

# %%
plt.title('NUMBER OF TERRORIST ACTIVITY EACH YEAR')
plt.rcParams['axes.labelsize']=12
sns.countplot(x=data.year)

# %% [markdown]
# * GLOBAL TERRORIST ACTIVITIES HAVE BBEN INCREASING SINCE 2012 UNTIL IT DECREASED IN 2016!

# %%
plt.title('MOST TARGETED MONTHS OF YEAR')
plt.rcParams['axes.labelsize']=15
clo=copy.deepcopy(data)
clo['month']=clo['month'].apply(lambda x:calendar.month_abbr[x])
sns.countplot(x=clo.month)

# %% [markdown]
# * ATTACKS HAVE BEEN LEAST IN DECEMBER, MAXIMUM IN MAY.
# * TERRORISTS FOUND MAY,JULY,JANUARY,AUGUST MOST PREFERABLE
# * MOST ATTACKS CONCENTRATED IN THE MID OF THE YEAR

# %%
a,c=[],[]
for g,d in data.groupby('country'):
        a.append(g)
        c.append(d.casualties.sum())
plt.figure(figsize=(10,4))
plt.grid(True)
plt.title('TOP 10 COUNTRIES AFFECTED COUNTRIES')
gc=pd.DataFrame(dict(casualties=c,country=a),columns=['casualties','country']).sort_values(ascending=False,by='casualties')[0:10]
sns.barplot(data=gc,y='country',x='casualties',ci=None)

# %% [markdown]
#  Iraq tops the country with highest no. of attacks followed by
# * Afghanistan
# * Nigeria
# * Syria
# * Pakistan

# %%
plt.title('MOST SUCCESSFUL ATTACK TECHNIQUES')
plt.grid(True)
sns.barplot(data=data,y='attack',x='casualties',ci=None)

# %% [markdown]
# * HOSTAGE-TAKING IN BARRICADE INCIDENTS CAUSED MAJOR CASUALTIES, MAY BE THERE DEMAND NOT FULFILLED ON TIME CAUSE THESE TERROR
# * UNARMED ASSAULTS AND BOMBIMG/EXPLOSION WAS THE SECOND MAJOR CAUSE OF CASUALITIES

# %%
plt.figure(figsize=(5,6))
plt.title('FAVOURITE TARGETS')
plt.grid(True)
sns.barplot(data=data,y='target',x='casualties',ci=None)

# %% [markdown]
# * NOT MANY PEOPLE COULD SAVE THEMSELVES IN AIRCRAFTS/AIRPORTS,RELIGIOUS PLACES OR TERRORIST/NON-STATE MILITIA

# %%
a,c=[],[]
for g,d in data.groupby('group'):
    if(d.casualties.count()>0):
        a.append(g)
        c.append(d.casualties.count())
plt.figure(figsize=(10,4))
print('NUMBER OF TERRORIST GROUPS: ',len(a))
plt.title('TOP 10 TERRORIST GROUPS WITH HIGHEST TERROR ATTACKS')
plt.grid(True)
gc=pd.DataFrame(dict(casualties=c,terrorist_group=a),columns=['casualties','terrorist_group']).sort_values(ascending=False,by='casualties')[1:11]
sns.barplot(data=gc,y='terrorist_group',x='casualties',ci=None)
# Out:
# NUMBER OF TERRORIST GROUPS:  753

# %% [markdown]
# * MOST SUCCESSFUL TERRORIST GROUPS - TALIBAN, ISIL

# %%
plt.figure(figsize=(15,5))
plt.rcParams['axes.labelsize']=17
sns.set_style('whitegrid')
plt.title('ACTIVITIES PER YEAR PER MONTH')
clo=copy.deepcopy(data)
clo['month']=clo['month'].apply(lambda x:calendar.month_abbr[x])
sns.countplot(x='month',hue='year',data=clo,palette='rainbow')

# %% [markdown]
# * IN JANUARY 2015, AROUND 1400 ATTCKS WERE MADE!

# %%
plt.figure(figsize=(7,7))
plt.rcParams['axes.labelsize']=15
sns.set_style('whitegrid')
plt.title('PROPERTY DAMAGE PER YEAR')
sns.countplot(x='year',hue='property_damg',data=data,palette='rainbow')

# %% [markdown]
# * NEGLIGIBLE PROPERTY DAMAGE GREATER THAN 1 MILLION DOLLAR HAS OCCURED
# * 2015 SAW A HUGE PROPERT LOSS CLOSE TO 3700 MILLION DOLLARS!

# %%
plt.figure(figsize=(9,5))
plt.title('5 MOST WEAPONS USED PER YEAR')
x=data[(data.weapon_type=='Explosives/Bombs/Dynamite')|(data.weapon_type=='Incendiary')\
       |(data.weapon_type=='Unknown')|(data.weapon_type=='Melee')|(data.weapon_type=='Firearms')]
sns.countplot(y='weapon_type',data=x,hue='year',palette='rainbow')

# %% [markdown]
# * IN 2016,2015,2014 EXPLOSIVES/BOMBS/DYNAMITES HAVE BEEN EXTENSIVELY USED!

# %%
plt.figure(figsize=(7,7))
plt.rcParams['axes.labelsize']=15
sns.set_style('whitegrid')
plt.title('MOST SUB-WEAPONS USED')
sns.countplot(y='weapon_subtype',data=data,palette='rainbow')

# %% [markdown]
# * UNKNOWN GUN TYPE, EXPLOSION TYPE WHICH HAVE NOT YET BEEN INSPECTED HAVE BEEN USED!
# * PROJECTILES AND VEHICLES TOO HAVE BEEN USED

# %%
w,con=[],[]
plt.title('10 ATTACKS WITH MAXIMUM WOUNDED')
for g,d in data.groupby('country'):
    w.append(d.wound.max())
    con.append(g)
ck=pd.DataFrame(dict(wounded=w,country=con),columns=['wounded','country']).sort_values(by='wounded',ascending=False)[0:10]
sns.barplot(data=ck,x='wounded',y='country',ci=None)

# %% [markdown]
# * IRAQ EVEN TOPS THE LIST OF WOUNDED

# %% [markdown]
# ### 4.2 Trend in activity of top 10 Terrorist Group

# %%
# Show the year only for top 10 group
data[data['group'].isin(data['group'].value_counts()[1:11].index)][['year','group']].head(15)
# Out:
#     year                            group
# 0   2012                       Al-Shabaab
# 2   2012                       Al-Shabaab
# 3   2012                          Taliban
# 7   2012                          Taliban
# 10  2012                          Taliban
# 11  2012                          Taliban
# 12  2012  Tehrik-i-Taliban Pakistan (TTP)
# 13  2012                       Boko Haram
# 14  2012                       Boko Haram
# 15  2012                       Boko Haram
# 16  2012                          Taliban
# 17  2012                          Taliban
# 18  2012                          Taliban
# 23  2012                          Taliban
# 24  2012                          Maoists

# %%
#Crosstab
xtab = pd.crosstab(data[data['group'].isin(data['group'].value_counts()[1:11].index)]['year'],\
data[data['group'].isin(data['group'].value_counts()[1:11].index)]['group'])
xtab
# Out:
# group  Al-Qaida in the Arabian Peninsula (AQAP)  Al-Shabaab  Boko Haram  \
# year
# 2012                                        192         205         384
# 2013                                        137         256         214
# 2014                                        270         608         429
# 2015                                        121         318         471
# 2016                                         75         456         223
#
# group  Houthi extremists (Ansar Allah)  \
# year
# 2012                                 0
# 2013                                16
# 2014                               104
# 2015                               292
# 2016                               297
#
# group  Islamic State of Iraq and the Levant (ISIL)  \
# year
# 2012                                             0
# 2013                                           344
# 2014                                           976
# 2015                                          1052
# 2016                                          1148
#
# group  Kurdistan Workers' Party (PKK)  Maoists  New People's Army (NPA)  \
# year
# 2012                              121      162                       83
# 2013                               18      157                      197
# 2014                               55      243                      270
# 2015                              324      257                      314
# 2016                              352      259                      165
#
# group  Taliban  Tehrik-i-Taliban Pakistan (TTP)
# year
# 2012       785                              168
# 2013       735                              153
# 2014       978                              163
# 2015      1071                              107
# 2016       964                               95

# %%
set(font_scale=1.4)
xtab.plot(color=sns.color_palette('Paired',10),figsize=(15,14))

# %% [markdown]
# * **Every terrorist group had its time peroid of activities and existence.**
# * **In 2012 to 2014 Taliban was the most active terrorist group.**
# * **ISIL came into existence after 2012 and had grew strong in very short period of time.**

# %% [markdown]
# ## 5. Terrorism In India

# %%
India = data[data['country']=='India']
India.head()
# Out:
#     year  month  day country               city  \
# 6   2012      1    2   India  Tinsukia district
# 24  2012      1    3   India           Baragada
# 35  2012      1    4   India          Srirampur
# 58  2012      1    5   India         Badarpanga
# 68  2012      1    7   India             Sopore
#
#                             attack                       target  \
# 6                Bombing/Explosion  Private Citizens & Property
# 24  Facility/Infrastructure Attack            Telecommunication
# 35               Bombing/Explosion  Private Citizens & Property
# 58               Bombing/Explosion                       Police
# 68                   Armed Assault                       Police
#
#                     target_inst                       target_pop nationality  \
# 6                Not Applicable                        Civilians       India
# 24                      Unknown                 Cell Phone Tower       India
# 35               Not Applicable                        Civilians       India
# 58  Indian Police Service (IPS)  Constable: Naha Chandra Pradhan       India
# 68  Indian Police Service (IPS)                   Police Station       India
#
#                                       group                weapon_type  \
# 6   United Liberation Front of Assam (ULFA)  Explosives/Bombs/Dynamite
# 24                                  Maoists                 Incendiary
# 35                                  Maoists  Explosives/Bombs/Dynamite
# 58                                  Maoists  Explosives/Bombs/Dynamite
# 68                   Hizbul Mujahideen (HM)  Explosives/Bombs/Dynamite
#
#          weapon_subtype                                         weapdetail  \
# 6               Grenade                                            Unknown
# 24  Gasoline or Alcohol         Husk and kerosene were used in the attack.
# 35            Land Mine                                            Unknown
# 58            Land Mine        A roadside landmine was used in the attack.
# 68              Grenade  Short-barrel AK-47 assault rifles were used in...
#
#     kill  wound                property_damg  ransom  casualties
# 6    0.0    3.0  Minor (likely < $1 million)     0.0         3.0
# 24   0.0    0.0                      Unknown     0.0         0.0
# 35   0.0    0.0                    no record     0.0         0.0
# 58   3.0    3.0  Minor (likely < $1 million)     0.0         6.0
# 68   1.0    0.0  Minor (likely < $1 million)     0.0         1.0

# %%
plt.figure(figsize=(15,8))
set(font_scale=1.4)
ax = sns.countplot(x = 'year', hue = 'attack', data = India, palette = 'rainbow')
ax.set_title('History of Terrorism in India',{'fontsize':30})
ax.set_xlabel('Year -> ')
ax.set_ylabel('Attack Frequency -> ')
ax.legend(loc=2)

# %% [markdown]
# * **Terrorism in India show somewhat same trend as seen globally i.e, bombing/Explosion topped in Attack type followed by Armed Assault in each year**
# * **2016 was the worst year for India as the attack frequency was highest**

# %% [markdown]
# ### Most Active Terrorist group in India

# %%
max_killed = India['kill'].max()
idx = India.loc[India.kill==max_killed].index[0]
idx
print('Maximum people killed in an attack are',max_killed,\
      '\nin the',India.at[idx,'city'],\
     '\nwhich was carried by',India.at[idx,'group'],'using',India.at[idx,'weapon_type'],\
     '\nand maximum people killed were',India.at[idx,'target'],'who were attack with',India.at[idx,'attack'])
# Out:
# Maximum people killed in an attack are 42.0
# in the Sukma district
# which was carried by Communist Party of India - Maoist (CPI-Maoist) using Firearms
# and maximum people killed were Police who were attack with Armed Assault

# %%
print("The no. of Terrorist group in India is",len(India['group'].unique()),'!')
# Out:
# The no. of Terrorist group in India is 119 !

# %%
# Finding the top 10 Terrorist group in India
grp_cas = India[India['group'].isin(India['group'].value_counts()[1:11].index)][['group','casualties']]\
.groupby('group').sum().reset_index()
grp_cas
# Out:
#                                                group  casualties
# 0     Communist Party of India - Maoist (CPI-Maoist)       649.0
# 1                      Garo National Liberation Army       128.0
# 2                             Hizbul Mujahideen (HM)       282.0
# 3                              Lashkar-e-Taiba (LeT)       481.0
# 4       National Democratic Front of Bodoland (NDFB)       248.0
# 5  National Socialist Council of Nagaland-Isak-Mu...        75.0
# 6                   People's Liberation Army (India)       114.0
# 7                 People's Liberation Front of India        57.0
# 8            United Liberation Front of Assam (ULFA)       237.0
# 9                                            Unknown       591.0

# %%
#Top 10 Terrorist group of India with there count of attacks
grp_cnt=India[India['group'].isin(India['group'].value_counts()[1:11].index)]['group'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'group','group':'count_of_attack'})
grp_cnt
# Out:
#                                                group  count_of_attack
# 0                                            Unknown              707
# 1     Communist Party of India - Maoist (CPI-Maoist)              317
# 2                      Garo National Liberation Army              121
# 3            United Liberation Front of Assam (ULFA)               93
# 4       National Democratic Front of Bodoland (NDFB)               77
# 5                             Hizbul Mujahideen (HM)               71
# 6                   People's Liberation Army (India)               60
# 7                              Lashkar-e-Taiba (LeT)               56
# 8  National Socialist Council of Nagaland-Isak-Mu...               41
# 9                 People's Liberation Front of India               38

# %%
# Merging the two data frame based on group to get the top 10
grp = grp_cas.merge(grp_cnt, on = 'group').sort_values(by='casualties',ascending=False)
grp
# Out:
#                                                group  casualties  \
# 0     Communist Party of India - Maoist (CPI-Maoist)       649.0
# 9                                            Unknown       591.0
# 3                              Lashkar-e-Taiba (LeT)       481.0
# 2                             Hizbul Mujahideen (HM)       282.0
# 4       National Democratic Front of Bodoland (NDFB)       248.0
# 8            United Liberation Front of Assam (ULFA)       237.0
# 1                      Garo National Liberation Army       128.0
# 6                   People's Liberation Army (India)       114.0
# 5  National Socialist Council of Nagaland-Isak-Mu...        75.0
# 7                 People's Liberation Front of India        57.0
#
#    count_of_attack
# 0              317
# 9              707
# 3               56
# 2               71
# 4               77
# 8               93
# 1              121
# 6               60
# 5               41
# 7               38

# %%
ax = grp.plot.barh(x='group',y=['casualties','count_of_attack'],stacked=True,figsize=(12,10))
ax.set_title('Top 10 most active Terrorist Group in India',{'fontsize':28})
ax.set_ylabel('Terrorist Group ->')
ax.set_xlabel('Count -> ')
# Out:
# Text(0.5, 0, 'Count -> ')

# %% [markdown]
# * **CPI-Maoist is the most active group in India**
# * **LeT has caused greater no. of casuality in less no. of attacks**
# * **Here Unknown refers mostly to the terrorists which cross border from Pakistan to Jammu and Kashmir and enters India but no terrorist group in Pakistan take responsibility of that to avoid suspicion. Next graph will clear it more**

# %% [markdown]
# ### Most Affected City in India

# %%
city_cnt=India[India['city'].isin(India['city'].value_counts()[1:11].index)]['city'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'city','city':'count'})
ax = city_cnt.plot.bar(x='city', figsize=(18,6))
ax.set_title('Top 10 Most Affected City In India',{'fontsize':25})
ax.set_xlabel('State -> ')
ax.set_ylabel('Attack Frequency -> ')
# Out:
# Text(0, 0.5, 'Attack Frequency -> ')

# %% [markdown]
# * **Srinagar is the most affected city followed by Sukma district, Bijapur district, Sopore and Latehar district**

# %% [markdown]
# ### Favourite Target of top 10 Terrorist Group in India

# %%
v1=India[India['group'].isin(India['group'].value_counts()[1:11].index)]
pd.crosstab(v1['group'],v1['target']).plot.bar(stacked=True,figsize=(18,12))
plt.legend(loc=0)
plt.suptitle('Favourite Target of Top 10 Terrorist Group',fontsize = 30)
plt.xlabel('Terrorist Group -->',{'fontsize':20})
plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0, 0.5, 'Attack Frequency -->')

# %% [markdown]
# * **CPI-Maoist mostly target Police, Private Citizen and Property**
# * **Private Citizen and Property was mostly damaged by these groups**

# %%
len(India.weapon_type.unique())
# Out:
# 8

# %%
explode=(0.0, 0.05, 0.0, 0.1, 0.15, 0.4, 0.15)
xattack=pd.crosstab(v1['weapon_type'],v1['group'],margins='All')
xattack=xattack[0:-1]
xattack.rename(columns={'All':'No. of Attack'},inplace=True)
xattack[0:-1].plot.pie(shadow=False,legend=False,y='No. of Attack',startangle=90,fontsize=10,figsize=(18,10),cmap='Set1',autopct='%1.1f%%',
                grid=True,explode=explode)
plt.axis('equal')
plt.legend(loc=0)
plt.suptitle('Weapon Type used by Top 10 Terrorist Group(Pie Chart)',fontsize = 22)
#plt.xlabel('Terrorist Group -->',{'fontsize':20})
#plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0.5, 0.98, 'Weapon Type used by Top 10 Terrorist Group(Pie Chart)')

# %% [markdown]
# ## 5. Terrorism In Iraq

# %%
Iraq = data[data['country']=='Iraq']
Iraq.head()
# Out:
#     year  month  day country          city             attack  \
# 40  2012      1    5    Iraq      Al-Batha  Bombing/Explosion
# 41  2012      1    5    Iraq       Baghdad  Bombing/Explosion
# 42  2012      1    5    Iraq       Baghdad  Bombing/Explosion
# 43  2012      1    5    Iraq  Al-Kazimiyah  Bombing/Explosion
# 44  2012      1    5    Iraq  Al-Kazimiyah  Bombing/Explosion
#
#                          target     target_inst     target_pop nationality  \
# 40  Private Citizens & Property  Not Applicable  Shia Pilgrims        Iraq
# 41  Private Citizens & Property  Not Applicable       Laborers        Iraq
# 42  Private Citizens & Property  Not Applicable       Laborers        Iraq
# 43  Private Citizens & Property  Not Applicable      Civilians        Iraq
# 44  Private Citizens & Property  Not Applicable      Civilians        Iraq
#
#                 group                weapon_type  \
# 40  Muslim extremists  Explosives/Bombs/Dynamite
# 41  Muslim extremists  Explosives/Bombs/Dynamite
# 42  Muslim extremists  Explosives/Bombs/Dynamite
# 43  Muslim extremists  Explosives/Bombs/Dynamite
# 44  Muslim extremists  Explosives/Bombs/Dynamite
#
#                              weapon_subtype  \
# 40  Suicide (carried bodily by human being)
# 41                                  Vehicle
# 42                                  Vehicle
# 43                                  Vehicle
# 44                                  Vehicle
#
#                               weapdetail  kill  wound property_damg  ransom  \
# 40                               Unknown  45.0   70.0     no record     0.0
# 41  A motorcycle was used in the attack.   6.0   19.0     no record     0.0
# 42  A motorcycle was used in the attack.   5.0   18.0     no record     0.0
# 43                               Unknown   8.0   16.0     no record     0.0
# 44                               Unknown   7.0   16.0     no record     0.0
#
#     casualties
# 40       115.0
# 41        25.0
# 42        23.0
# 43        24.0
# 44        23.0

# %%
plt.figure(figsize=(15,8))
set(font_scale=1.4)
ax = sns.countplot(x = 'year', hue = 'attack', data = Iraq, palette = 'rainbow')
ax.set_title('History of Terrorism in Iraq',{'fontsize':30})
ax.set_xlabel('Year -> ')
ax.set_ylabel('Attack Frequency -> ')
ax.legend(loc=2)

# %% [markdown]
# * **Terrorism in Iraq show somewhat same trend as seen globally i.e, bombing/Explosion topped in Attack type.**
# * **2016 was the worst year for Iraq as the attack frequency was highest.**
# * **There were almost few terrorism activities in Iraq until 2012 and 2013.**
# * **We can see almost 3 fold rise in attacks after 2015.**

# %% [markdown]
# ### Most Active Terrorist group in Iraq

# %%
max_killed = Iraq['kill'].max()
idx = Iraq.loc[Iraq.kill==max_killed].index[0]
idx
print('Maximum people killed in an attack are',max_killed,\
      '\nin the',Iraq.at[idx,'city'],\
     '\nwhich was carried by',Iraq.at[idx,'group'],'using',Iraq.at[idx,'weapon_type'],\
     '\nand maximum people killed were',Iraq.at[idx,'target'],'who were attack with',Iraq.at[idx,'attack'])
# Out:
# Maximum people killed in an attack are 1500.0
# in the Tikrit
# which was carried by Islamic State of Iraq and the Levant (ISIL) using Firearms
# and maximum people killed were Military who were attack with Hostage Taking (Kidnapping)

# %%
print("The no. of Terrorist group in Iraq is",len(Iraq['group'].unique()),'!')
# Out:
# The no. of Terrorist group in Iraq is 19 !

# %%
# Finding the top 10 Terrorist group in Iraq
grp_cas = Iraq[Iraq['group'].isin(Iraq['group'].value_counts()[1:11].index)][['group','casualties']]\
.groupby('group').sum().reset_index()
grp_cas
# Out:
#                                                group  casualties
# 0                              Al-Naqshabandiya Army       415.0
# 1                                   Al-Qaida in Iraq      4846.0
# 2                                 Asa'ib Ahl al-Haqq       126.0
# 3        Islamic State of Iraq and the Levant (ISIL)     45972.0
# 4                Kurdish Democratic Party-Iraq (KDP)         1.0
# 5  Military Council of the Tribal Revolutionaries...       199.0
# 6                                       Mukhtar Army       165.0
# 7                                  Muslim extremists       438.0
# 8                 Popular Mobilization Forces (Iraq)         0.0
# 9                                          Tribesmen        20.0

# %%
#Top 10 Terrorist group of Iraq with there count of attacks
grp_cnt=Iraq[Iraq['group'].isin(Iraq['group'].value_counts()[1:11].index)]['group'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'group','group':'count_of_attack'})
grp_cnt
# Out:
#                                                group  count_of_attack
# 0        Islamic State of Iraq and the Levant (ISIL)             2959
# 1                                   Al-Qaida in Iraq              359
# 2                              Al-Naqshabandiya Army               34
# 3                                  Muslim extremists               25
# 4  Military Council of the Tribal Revolutionaries...               19
# 5                                 Asa'ib Ahl al-Haqq                7
# 6                                          Tribesmen                4
# 7                                       Mukhtar Army                4
# 8                 Popular Mobilization Forces (Iraq)                3
# 9                Kurdish Democratic Party-Iraq (KDP)                1

# %%
# Merging the two data frame based on group to get the top 10
grp = grp_cas.merge(grp_cnt, on = 'group').sort_values(by='casualties',ascending=False)
grp
# Out:
#                                                group  casualties  \
# 3        Islamic State of Iraq and the Levant (ISIL)     45972.0
# 1                                   Al-Qaida in Iraq      4846.0
# 7                                  Muslim extremists       438.0
# 0                              Al-Naqshabandiya Army       415.0
# 5  Military Council of the Tribal Revolutionaries...       199.0
# 6                                       Mukhtar Army       165.0
# 2                                 Asa'ib Ahl al-Haqq       126.0
# 9                                          Tribesmen        20.0
# 4                Kurdish Democratic Party-Iraq (KDP)         1.0
# 8                 Popular Mobilization Forces (Iraq)         0.0
#
#    count_of_attack
# 3             2959
# 1              359
# 7               25
# 0               34
# 5               19
# 6                4
# 2                7
# 9                4
# 4                1
# 8                3

# %%
ax = grp.plot.barh(x='group',y=['casualties','count_of_attack'],stacked=True,figsize=(12,10))
ax.set_title('Top 10 most active Terrorist Group in Iraq',{'fontsize':28})
ax.set_ylabel('Terrorist Group ->')
ax.set_xlabel('Count -> ')
# Out:
# Text(0.5, 0, 'Count -> ')

# %% [markdown]
# * **ISIL is the most active group in Iraq**
# * **AI-Qaida has caused greater no. of casuality in less no. of attacks**

# %% [markdown]
# ### Most Affected City in Iraq

# %%
city_cnt=Iraq[Iraq['city'].isin(Iraq['city'].value_counts()[1:11].index)]['city'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'city','city':'count'})
ax = city_cnt.plot.bar(x='city', figsize=(18,6))
ax.set_title('Top 10 Most Affected City In Iraq',{'fontsize':25})
ax.set_xlabel('State -> ')
ax.set_ylabel('Attack Frequency -> ')
# Out:
# Text(0, 0.5, 'Attack Frequency -> ')

# %% [markdown]
# * **Mosul is the most affected city followed by Ramadi, Fallujah and Madain**
# * **Mosul witnessed more than twice number of attacks than the rest cities except Ramadi.**

# %% [markdown]
# ### Favourite Target of top 10 Terrorist Group in Iraq

# %%
v1=Iraq[Iraq['group'].isin(Iraq['group'].value_counts()[1:11].index)]
pd.crosstab(v1['group'],v1['target']).plot.bar(stacked=True,figsize=(18,12))
plt.legend(loc=0)
plt.suptitle('Favourite Target of Top 10 Terrorist Group',fontsize = 30)
plt.xlabel('Terrorist Group -->',{'fontsize':20})
plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0, 0.5, 'Attack Frequency -->')

# %% [markdown]
# * **ISIL mostly target Police, Private Citizen and Property,Military and Business**
# * **Private Citizen and Property was mostly damaged by these groups**

# %%
len(Iraq.weapon_type.unique())
# Out:
# 8

# %%
explode=(0.0, 0.05, 0.0, 0.0, 0.15, 0.4, 0.15)
xattack=pd.crosstab(v1['weapon_type'],v1['group'],margins='All')
xattack=xattack[0:-1]
xattack.rename(columns={'All':'No. of Attack'},inplace=True)
xattack[0:-1].plot.pie(shadow=False,legend=False,y='No. of Attack',startangle=135,fontsize=18,figsize=(18,10),cmap='Set1',autopct='%1.1f%%',
                grid=True,explode=explode)
plt.axis('equal')
plt.legend(loc=0)
plt.suptitle('Weapon Type used by Top 10 Terrorist Group(Pie Chart)',fontsize = 22)
#plt.xlabel('Terrorist Group -->',{'fontsize':20})
#plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0.5, 0.98, 'Weapon Type used by Top 10 Terrorist Group(Pie Chart)')

# %% [markdown]
# * **Explosives were mainly used by majority of the terrorist groups to spread its terror.**

# %% [markdown]
# ## 6. Terrorism In Bangladesh

# %%
Bangladesh = data[data['country']=='Bangladesh']
Bangladesh.head()
# Out:
#       year  month  day     country        city                       attack  \
# 1152  2012      4   29  Bangladesh       Dhaka            Bombing/Explosion
# 1153  2012      4   29  Bangladesh      Khulna            Bombing/Explosion
# 1423  2012      5   19  Bangladesh  Luxmichari                Assassination
# 1432  2012      5   20  Bangladesh   Rangamati            Bombing/Explosion
# 1450  2012      5   22  Bangladesh      Raozan  Hostage Taking (Kidnapping)
#
#                             target  \
# 1152          Government (General)
# 1153       Educational Institution
# 1423  Terrorists/Non-State Militia
# 1432   Private Citizens & Property
# 1450       Violent Political Party
#
#                                            target_inst  \
# 1152                            Bangladesh Secretariat
# 1153                                 Sundarban College
# 1423  Parbatya Chattagram Jana Sanghati Samity (PCJSS)
# 1432                     Pahari Chhatra Parishad (PCP)
# 1450                Bangladesh Nationalist Party (BNP)
#
#                        target_pop nationality  \
# 1152                Home Ministry  Bangladesh
# 1153               College Campus  Bangladesh
# 1423  Unit president: Anil Chakma  Bangladesh
# 1432                     Students  Bangladesh
# 1450                      Leaders  Bangladesh
#
#                                                   group  \
# 1152                 Bangladesh Nationalist Party (BNP)
# 1153                               Pro Hartal Activists
# 1423  United People's Democratic Front (UPDF) - Bang...
# 1432  United People's Democratic Front (UPDF) - Bang...
# 1450                                       Awami League
#
#                     weapon_type          weapon_subtype  \
# 1152  Explosives/Bombs/Dynamite    Other Explosive Type
# 1153  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 1423                   Firearms        Unknown Gun Type
# 1432  Explosives/Bombs/Dynamite                 Grenade
# 1450                      Melee      Hands, Feet, Fists
#
#                                              weapdetail  kill  wound  \
# 1152  Two thrown explosive devices consisting of exp...   0.0    0.0
# 1153                                            Unknown   0.0    0.0
# 1423                                            Unknown   1.0    2.0
# 1432                                            Unknown   0.0   14.0
# 1450                                            Unknown   0.0    5.0
#
#                     property_damg  ransom  casualties
# 1152  Minor (likely < $1 million)     0.0         0.0
# 1153                    no record     0.0         0.0
# 1423                    no record     0.0         3.0
# 1432                    no record     0.0        14.0
# 1450                    no record     0.0         5.0

# %%
plt.figure(figsize=(15,8))
set(font_scale=1.4)
ax = sns.countplot(x = 'year', hue = 'attack', data = Bangladesh, palette = 'rainbow')
ax.set_title('History of Terrorism in Bangladesh',{'fontsize':30})
ax.set_xlabel('Year -> ')
ax.set_ylabel('Attack Frequency -> ')
ax.legend(loc=2)

# %% [markdown]
# * **Terrorism in Bangladesh show somewhat same trend as seen globally i.e, bombing/Explosion topped in Attack type.**
# * **2015 was the worst year for Bangladesh as the attack frequency was highest.**
# * **There were almost few terrorism activities in 2012 and 2014 respectively.**

# %% [markdown]
# ### Most Active Terrorist group in Bangladesh

# %%
max_killed = Bangladesh['kill'].max()
idx = Bangladesh.loc[Bangladesh.kill==max_killed].index[0]
idx
print('Maximum people killed in an attack are',max_killed,\
      '\nin the',Bangladesh.at[idx,'city'],\
     '\nwhich was carried by',Bangladesh.at[idx,'group'],'using',Bangladesh.at[idx,'weapon_type'],\
     '\nand maximum people killed were',Bangladesh.at[idx,'target'],'who were attack with',Bangladesh.at[idx,'attack'])
# Out:
# Maximum people killed in an attack are 28.0
# in the Dhaka
# which was carried by Islamic State in Bangladesh using Explosives/Bombs/Dynamite
# and maximum people killed were Business who were attack with Hostage Taking (Barricade Incident)

# %%
print("The no. of Terrorist group in Bangladesh is",len(Bangladesh['group'].unique()),'!')
# Out:
# The no. of Terrorist group in Bangladesh is 17 !

# %%
# Finding the top 10 Terrorist group in Bangladesh
grp_cas = Bangladesh[Bangladesh['group'].isin(Bangladesh['group'].value_counts()[1:11].index)][['group','casualties']]\
.groupby('group').sum().reset_index()
grp_cas
# Out:
#                                                group  casualties
# 0                Al-Qaida in the Indian Subcontinent        11.0
# 1                             Ansarullah Bangla Team        43.0
# 2                                       Awami League        20.0
# 3                 Bangladesh Nationalist Party (BNP)        54.0
# 4                      Hizb al-Tahrir al-Islami (HT)         1.0
# 5                        Islamic State in Bangladesh       231.0
# 6              Jama'atul Mujahideen Bangladesh (JMB)        27.0
# 7                       Jamaat-E-Islami (Bangladesh)       162.0
# 8                               Pro Hartal Activists       157.0
# 9  United People's Democratic Front (UPDF) - Bang...        18.0

# %%
#Top 10 Terrorist group of Bangladesh with there count of attacks
grp_cnt=Bangladesh[Bangladesh['group'].isin(Bangladesh['group'].value_counts()[1:11].index)]\
['group'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'group','group':'count_of_attack'})
grp_cnt
# Out:
#                                                group  count_of_attack
# 0                               Pro Hartal Activists               87
# 1                       Jamaat-E-Islami (Bangladesh)               53
# 2                 Bangladesh Nationalist Party (BNP)               50
# 3                        Islamic State in Bangladesh               33
# 4              Jama'atul Mujahideen Bangladesh (JMB)               11
# 5                                       Awami League               11
# 6                             Ansarullah Bangla Team                9
# 7                Al-Qaida in the Indian Subcontinent                6
# 8  United People's Democratic Front (UPDF) - Bang...                5
# 9                      Hizb al-Tahrir al-Islami (HT)                1

# %%
# Merging the two data frame based on group to get the top 10
grp = grp_cas.merge(grp_cnt, on = 'group').sort_values(by='casualties',ascending=False)
grp
# Out:
#                                                group  casualties  \
# 5                        Islamic State in Bangladesh       231.0
# 7                       Jamaat-E-Islami (Bangladesh)       162.0
# 8                               Pro Hartal Activists       157.0
# 3                 Bangladesh Nationalist Party (BNP)        54.0
# 1                             Ansarullah Bangla Team        43.0
# 6              Jama'atul Mujahideen Bangladesh (JMB)        27.0
# 2                                       Awami League        20.0
# 9  United People's Democratic Front (UPDF) - Bang...        18.0
# 0                Al-Qaida in the Indian Subcontinent        11.0
# 4                      Hizb al-Tahrir al-Islami (HT)         1.0
#
#    count_of_attack
# 5               33
# 7               53
# 8               87
# 3               50
# 1                9
# 6               11
# 2               11
# 9                5
# 0                6
# 4                1

# %%
ax = grp.plot.barh(x='group',y=['casualties','count_of_attack'],stacked=True,figsize=(12,10))
ax.set_title('Top 10 most active Terrorist Group in Bangladesh',{'fontsize':28})
ax.set_ylabel('Terrorist Group ->')
ax.set_xlabel('Count -> ')
# Out:
# Text(0.5, 0, 'Count -> ')

# %% [markdown]
# * **Islamic State in Bangladesh is the most active group followed by Jamaat-E-Islami and Pro Hartal Activists**
# * **Islamic State in Bangladesh has caused greater no. of casuality in less no. of attacks**
# * **BNP witnessed equal casualties in comparison to the ratio of attacks**

# %% [markdown]
# ### Most Affected City in Bangladesh

# %%
city_cnt=Bangladesh[Bangladesh['city'].isin(Bangladesh['city'].value_counts()[1:11].index)]['city'].value_counts().to_frame().reset_index()\
.rename(columns={'index':'city','city':'count'})
ax = city_cnt.plot.bar(x='city', figsize=(18,6))
ax.set_title('Top 10 Most Affected City In Bangladesh',{'fontsize':25})
ax.set_xlabel('State -> ')
ax.set_ylabel('Attack Frequency -> ')
# Out:
# Text(0, 0.5, 'Attack Frequency -> ')

# %% [markdown]
# * **Chittagong is the most affected city followed by Rajshahi, Jessore and Khulna**
# * **Chittagong witnessed thrice number of attacks than the rest cities except Rajshahi.**

# %% [markdown]
# ### Favourite Target of top 10 Terrorist Group in Bangladesh

# %%
v1=Bangladesh[Bangladesh['group'].isin(Bangladesh['group'].value_counts()[1:11].index)]
pd.crosstab(v1['group'],v1['target']).plot.bar(stacked=True,figsize=(18,12))
plt.legend(loc=0)
plt.suptitle('Favourite Target of Top 10 Terrorist Group',fontsize = 30)
plt.xlabel('Terrorist Group -->',{'fontsize':20})
plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0, 0.5, 'Attack Frequency -->')

# %% [markdown]
# * **Pro Hartal Activists mostly target Government(Diplomatic), Private Citizen and Property,Military and Business**

# %%
len(Bangladesh.weapon_type.unique())
# Out:
# 6

# %%
xattack=pd.crosstab(v1['weapon_type'],v1['group'],margins='All')
xattack=xattack[0:-1]
xattack.rename(columns={'All':'No. of Attack'},inplace=True)
xattack[0:-1].plot.pie(shadow=False,legend=False,y='No. of Attack',startangle=135,fontsize=18,figsize=(18,10),cmap='Set1',autopct='%1.1f%%',
                grid=True)
plt.axis('equal')
plt.legend(loc=0)
plt.suptitle('Weapon Type used by Top 10 Terrorist Group(Pie Chart)',fontsize = 22)
#plt.xlabel('Terrorist Group -->',{'fontsize':20})
#plt.ylabel('Attack Frequency -->',{'fontsize':20})
# Out:
# Text(0.5, 0.98, 'Weapon Type used by Top 10 Terrorist Group(Pie Chart)')

# %% [markdown]
# * **Explosives were mainly used by majority of the terrorist groups to spread its terror.**
# * **The ratio of explosives to firearms is approximately 7:1.**
