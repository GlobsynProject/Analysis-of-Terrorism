# %%
# import module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the Data Set in data
try:
    data = pd.read_csv("D:/Dataset.csv")
except:
    print("file not found...")
data.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'city', 'attacktype1_txt',
#        'targtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'gname',
#        'weaptype1_txt', 'weapsubtype1_txt', 'weapdetail', 'nkill', 'nwound',
#        'propextent_txt', 'ransomamt'],
#       dtype='object')

# %%
# Rename the columns
data.rename({'iyear':'year','imonth':'month','iday':'day','country_txt':'country','attacktype1_txt':'attack',\
             'targtype1_txt':'target', 'corp1':'target_inst', 'target1':'target_pop', 'natlty1_txt':'nationality',\
             'gname':'group','weaptype1_txt':'weapon_type', 'weapsubtype1_txt':'weapon_subtype', 'nkill':'kill', \
             'nwound':'wound','propextent_txt':'property_damg', 'ransomamt':'ransom'},axis='columns',inplace=True)
data.head()
# Out:
#    year  month  day                           country      city  \
# 0  2012      1    1                             Kenya   Garissa
# 1  2012      1    1                          Pakistan       Sui
# 2  2012      1    1                             Kenya   Garissa
# 3  2012      1    1                       Afghanistan     Karez
# 4  2012      1    1  Democratic Republic of the Congo  Shabunda
#
#                            attack                       target  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
#
#                                          target_inst target_pop  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
#
#                         nationality  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
#
#                                                group  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
#
#                  weapon_type          weapon_subtype  \
# 0  Explosives/Bombs/Dynamite                 Grenade
# 1  Explosives/Bombs/Dynamite               Land Mine
# 2  Explosives/Bombs/Dynamite                 Grenade
# 3  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 4                 Incendiary              Arson/Fire
#
#                                           weapdetail  kill  wound  \
# 0  Two grenades and AK-47 assault rifles were use...   3.0   14.0
# 1                                                NaN   4.0    3.0
# 2                                                NaN   2.0   14.0
# 3                                                NaN   0.0    0.0
# 4                                                NaN  18.0    5.0
#
#                  property_damg  ransom
# 0  Minor (likely < $1 million)     NaN
# 1  Minor (likely < $1 million)     NaN
# 2  Minor (likely < $1 million)     NaN
# 3                      Unknown     NaN
# 4  Minor (likely < $1 million)     NaN

# %%
data.describe()
# Out:
#                year         month           day          kill         wound  \
# count  43915.000000  43915.000000  43915.000000  41290.000000  39313.000000
# mean    2014.688079      6.442537     15.664716      3.110463      3.504006
# std        1.229350      3.390650      8.778536     13.343306     13.988988
# min     2012.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2014.000000      4.000000      8.000000      0.000000      0.000000
# 50%     2015.000000      6.000000     15.000000      1.000000      0.000000
# 75%     2016.000000      9.000000     23.000000      2.000000      3.000000
# max     2016.000000     12.000000     31.000000   1500.000000   1500.000000
#
#              ransom
# count  2.730000e+02
# mean   4.066460e+06
# std    2.180638e+07
# min   -9.900000e+01
# 25%   -9.900000e+01
# 50%    1.586045e+04
# 75%    2.189562e+05
# max    2.000000e+08

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='viridis')

# %%
p=data[data.country=='India']
p.kill.describe()
# Out:
# count    3155.000000
# mean        0.598732
# std         1.744454
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        42.000000
# Name: kill, dtype: float64

# %%
plt.plot(p.year,p.kill)
plt.show()

# %%
data["casualties"]=data["kill"]+data["wound"]

# %%
data.head()
# Out:
#    year  month  day                           country      city  \
# 0  2012      1    1                             Kenya   Garissa
# 1  2012      1    1                          Pakistan       Sui
# 2  2012      1    1                             Kenya   Garissa
# 3  2012      1    1                       Afghanistan     Karez
# 4  2012      1    1  Democratic Republic of the Congo  Shabunda
#
#                            attack                       target  \
# 0                   Armed Assault                     Business
# 1               Bombing/Explosion                     Military
# 2                   Armed Assault                     Business
# 3               Bombing/Explosion                     Military
# 4  Facility/Infrastructure Attack  Private Citizens & Property
#
#                                          target_inst target_pop  \
# 0                                          Locus Pub        Bar
# 1                                Frontier Corps (FC)   Soldiers
# 2                                            Unknown        Bar
# 3  North Atlantic Treaty Organization (NATO): Int...    Vehicle
# 4                                     Not Applicable  Civilians
#
#                         nationality  \
# 0                             Kenya
# 1                          Pakistan
# 2                             Kenya
# 3                     International
# 4  Democratic Republic of the Congo
#
#                                                group  \
# 0                                         Al-Shabaab
# 1                       Baloch Republican Army (BRA)
# 2                                         Al-Shabaab
# 3                                            Taliban
# 4  Democratic Front for the Liberation of Rwanda ...
#
#                  weapon_type          weapon_subtype  \
# 0  Explosives/Bombs/Dynamite                 Grenade
# 1  Explosives/Bombs/Dynamite               Land Mine
# 2  Explosives/Bombs/Dynamite                 Grenade
# 3  Explosives/Bombs/Dynamite  Unknown Explosive Type
# 4                 Incendiary              Arson/Fire
#
#                                           weapdetail  kill  wound  \
# 0  Two grenades and AK-47 assault rifles were use...   3.0   14.0
# 1                                                NaN   4.0    3.0
# 2                                                NaN   2.0   14.0
# 3                                                NaN   0.0    0.0
# 4                                                NaN  18.0    5.0
#
#                  property_damg  ransom  casualties
# 0  Minor (likely < $1 million)     NaN        17.0
# 1  Minor (likely < $1 million)     NaN         7.0
# 2  Minor (likely < $1 million)     NaN        16.0
# 3                      Unknown     NaN         0.0
# 4  Minor (likely < $1 million)     NaN        23.0

# %%
data.corr()
# Out:
#                 year     month       day      kill     wound    ransom  \
# year        1.000000 -0.032845 -0.002996 -0.019340 -0.025865 -0.165084
# month      -0.032845  1.000000  0.002112  0.005468 -0.001070  0.077339
# day        -0.002996  0.002112  1.000000 -0.008516 -0.001725  0.041875
# kill       -0.019340  0.005468 -0.008516  1.000000  0.364357  0.029284
# wound      -0.025865 -0.001070 -0.001725  0.364357  1.000000 -0.038720
# ransom     -0.165084  0.077339  0.041875  0.029284 -0.038720  1.000000
# casualties -0.027597  0.003335 -0.001706  0.718234  0.909665  0.019981
#
#             casualties
# year         -0.027597
# month         0.003335
# day          -0.001706
# kill          0.718234
# wound         0.909665
# ransom        0.019981
# casualties    1.000000

# %%
sns.barplot(data=data,x='year',y='casualties',ci=None)

# %%
sns.barplot(data=data,x='month',y='casualties',ci=None)

# %%
plt.figure(figsize=(30,15))
sns.barplot(data=data,y='country',x='casualties',ci=None)

# %%
plt.figure(figsize=(20,9))
sns.barplot(data=data,x='attack',y='casualties',ci=None)

# %%
plt.figure(figsize=(20,9))
sns.barplot(data=data,x='target',y='casualties',ci=None)
